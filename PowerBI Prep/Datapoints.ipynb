# %%
# %sql
select * from dataplatform01_central_dev_catalog_01.custom_sap_bo.webi_dictionary_linage

select * from dataplatform01_central_dev_catalog_01.custom_sap_bo.webi_variables_linage
