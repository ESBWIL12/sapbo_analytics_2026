# %%
# %sql
select count(distinct document_id)
from dataplatform01_central_dev_catalog_01.bronze_raw_sap_bo.webi_document_extraction_summary
where to_date(ingestion_ts) = current_date()
-- order by count desc

-- parameter_table="dataplatform01_central_dev_catalog_01.bronze_raw_sap_bo.webi_parameters"
-- variable_table="dataplatform01_central_dev_catalog_01.bronze_raw_sap_bo.webi_variables"
-- sql_table="dataplatform01_central_dev_catalog_01.bronze_raw_sap_bo.webi_metadata_cms"
-- extract_summary_table="dataplatform01_central_dev_catalog_01.bronze_raw_sap_bo.webi_document_extraction_summary"

# %%
# %sql
select count(distinct document_id) from 
dataplatform01_central_dev_catalog_01.bronze_raw_sap_bo.webi_parameters
where to_date(ingestion_ts) = current_date()

# %%
# %sql
select count(distinct document_id) from 
dataplatform01_central_dev_catalog_01.bronze_raw_sap_bo.webi_variables
where to_date(ingestion_ts) = current_date()

# %%
# %sql
select count(distinct document_id) from 
dataplatform01_central_dev_catalog_01.bronze_raw_sap_bo.webi_metadata_cms
where to_date(ingestion_ts) = current_date()

# %%
# %sql
select count(distinct document_id) From dataplatform01_central_dev_catalog_01.bronze_raw_sap_bo.webi_datadictionary
where to_timestamp(ingestion_ts) > current_date() + interval 12 hours
-- order by to_timestamp(ingestion_ts) asc

# %%
# %sql
select count(distinct document_id) From dataplatform01_central_dev_catalog_01.bronze_raw_sap_bo.webi_excel
where to_timestamp(ingestion_ts) > current_date() + interval 12 hours
-- order by to_timestamp(ingestion_ts) asc
