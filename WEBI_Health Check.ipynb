# %%
# %sql
select month(ingestion_ts) as ingestion_month, scheduled, count(distinct Document_Id) 
from dataplatform01_central_dev_catalog_01.bronze_raw_sap_bo.webi_full_records_metadata
group by month(ingestion_ts), scheduled


-- select * from

# %%
# %sql
ALTER TABLE dataplatform01_central_dev_catalog_01.bronze_raw_sap_bo.webi_full_records_metadata
ADD COLUMN ingestion_ts TIMESTAMP
